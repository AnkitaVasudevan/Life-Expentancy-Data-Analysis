# %%
import pandas as pd
import numpy as np
from prettytable import PrettyTable
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('D:/3rd Semester/MiniProjects/Data Science/Life Expectancy DataRaw.csv')
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
df.shape # Gives the dimensions of the data set
df.info()  # Gives the information of the type of data in each coloumn
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %%
df.isnull().sum() #Finds the null values in each column , columns that aren't relevant are dropped.
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  10-19 years              34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
df = df.drop(['Hepatitis B','Polio','Total expenditure',' thinness 5-9 years','Schooling','under-five deaths '],axis=1)

# %%
df.fillna(value=0, inplace=True)

# %%
print(df.shape)
df.head() #Dropped the number of columns to 16 from 22.
# Out:
# (2938, 16)
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Measles    BMI   \
# 0             62     0.01               71.279624      1154   19.1
# 1             64     0.01               73.523582       492   18.6
# 2             66     0.01               73.219243       430   18.1
# 3             69     0.01               78.184215      2787   17.6
# 4             71     0.01                7.097109      3013   17.2
#
#    Diphtheria    HIV/AIDS         GDP  Population   thinness  10-19 years  \
# ...

# %%
df.isnull().sum()
# Out:
# Country                            0
# Year                               0
# Status                             0
# Life expectancy                    0
# Adult Mortality                    0
# infant deaths                      0
# Alcohol                            0
# percentage expenditure             0
# Measles                            0
#  BMI                               0
# Diphtheria                         0
#  HIV/AIDS                          0
# GDP                                0
# Population                         0
#  thinness  10-19 years             0
# Income composition of resources    0
# dtype: int64

# %%
#Capitalisation of the categorical data
df['Country'] = df['Country'].str.upper()
df['Status'] = df['Status'].str.upper()
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  AFGHANISTAN  2015  DEVELOPING              65.0            263.0
# 1  AFGHANISTAN  2014  DEVELOPING              59.9            271.0
# 2  AFGHANISTAN  2013  DEVELOPING              59.9            268.0
# 3  AFGHANISTAN  2012  DEVELOPING              59.5            272.0
# 4  AFGHANISTAN  2011  DEVELOPING              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Measles    BMI   \
# 0             62     0.01               71.279624      1154   19.1
# 1             64     0.01               73.523582       492   18.6
# 2             66     0.01               73.219243       430   18.1
# 3             69     0.01               78.184215      2787   17.6
# 4             71     0.01                7.097109      3013   17.2
#
#    Diphtheria    HIV/AIDS         GDP  Population   thinness  10-19 years  \
# 0         65.0        0.1  584.259210  33736494.0                    17.2
# ...

# %%
df = df[df['Year'] >2010]

# %%
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  AFGHANISTAN  2015  DEVELOPING              65.0            263.0
# 1  AFGHANISTAN  2014  DEVELOPING              59.9            271.0
# 2  AFGHANISTAN  2013  DEVELOPING              59.9            268.0
# 3  AFGHANISTAN  2012  DEVELOPING              59.5            272.0
# 4  AFGHANISTAN  2011  DEVELOPING              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Measles    BMI   \
# 0             62     0.01               71.279624      1154   19.1
# 1             64     0.01               73.523582       492   18.6
# 2             66     0.01               73.219243       430   18.1
# 3             69     0.01               78.184215      2787   17.6
# 4             71     0.01                7.097109      3013   17.2
#
#    Diphtheria    HIV/AIDS         GDP  Population   thinness  10-19 years  \
# 0         65.0        0.1  584.259210  33736494.0                    17.2
# ...

# %%
df.shape
# Out:
# (925, 16)

# %%
## MEAN and VARIANCE

# %%
p=PrettyTable()
p.field_names=["Parameter","Mean","Variance"]

# %%
lfm=df['Life expectancy '].mean()
x=df['Life expectancy '].std()
lfv=x**2
amm=df['Adult Mortality'].mean()
y=df['Adult Mortality'].std()
amv=y**2
idm=df['infant deaths'].mean()
z=df['infant deaths'].std()
idv=z**2
am=df['Alcohol'].mean()
a=df['Alcohol'].std()
av=a**2
pem=df['percentage expenditure'].mean()
b=df['percentage expenditure'].std()
pev=b**2
mm=df['Measles '].mean()
c=df['Measles '].std()
mv=c**2
bm=df[' BMI '].mean()
d=df[' BMI '].std()
bv=d**2
dm=df['Diphtheria '].mean()
e=df['Diphtheria '].std()
dv=e**2
ham=df[' HIV/AIDS'].mean()
f=df[' HIV/AIDS'].std()
hav=f**2
gm=df['GDP'].mean()
g=df['GDP'].std()
gv=g**2
pm=df['Population'].mean()
h=df['Population'].std()
pv=h**2
tm=df[' thinness  10-19 years'].mean()
i=df[' thinness  10-19 years'].std()
tv=i**2
icm=df['Income composition of resources'].mean()
j=df['Income composition of resources'].std()
icv=j**2

p.add_row(["Life expectancy",lfm,lfv])
p.add_row(["Adult mortality",amm,amv])
p.add_row(["Infant deaths",idm,idv])
p.add_row(["Alcohol",am,av])
p.add_row(["Percentage expenditure",pem,pev])
p.add_row(["Measles",mm,mv])
p.add_row(["BMI",bm,bv])
p.add_row(["Diphtheria",dm,dv])
p.add_row(["HIv/AIDS",ham,hav])
p.add_row(["GDP",gm,gv])
p.add_row(["Population",pm,pv])
p.add_row(["Thinness 1-19 Years",tm,tv])
p.add_row(["Income composition of resources",icm,icv])

print(p)
# Out:
# +---------------------------------+--------------------+----------------------+
# |            Parameter            |        Mean        |       Variance       |
# +---------------------------------+--------------------+----------------------+
# |         Life expectancy         | 70.42248648648648  |  125.89893104013107  |
# |         Adult mortality         | 149.49513513513514 |  11299.89310401309   |
# |          Infant deaths          | 25.087567567567568 |  8195.950115830095   |
# |             Alcohol             | 3.2610486486486616 |  16.52046047923236   |
# |      Percentage expenditure     | 777.0366105048689  |  5017554.592007256   |
# |             Measles             | 1597.881081081081  |  68605892.18281327   |
# |               BMI               |  40.6432432432433  |  453.70011934011814  |
# |            Diphtheria           | 85.59027027027027  |  428.48886626886593  |
# |             HIv/AIDS            | 0.8205405405405485 |  3.2061577161577053  |
# ...

# %%
## NORMALIZATION

# %%
from sklearn.preprocessing import normalize

x_array = np.array([df['Alcohol'],df['percentage expenditure'],df[' BMI '],df['GDP'],df[' thinness  10-19 years']])
print(x_array)
normalized_X = normalize(x_array)
# Out:
# [[1.00000000e-02 1.00000000e-02 1.00000000e-02 ... 6.39000000e+00
#   6.09000000e+00 6.00000000e+00]
#  [7.12796236e+01 7.35235817e+01 7.32192427e+01 ... 1.06667073e+01
#   9.26023364e+01 6.37505303e+01]
#  [1.91000000e+01 1.86000000e+01 1.81000000e+01 ... 3.80000000e+00
#   3.30000000e+00 2.99000000e+01]
#  [5.84259210e+02 6.12696514e+02 6.31744976e+02 ... 1.11227396e+02
#   9.55648466e+02 8.39927936e+02]
#  [1.72000000e+01 1.75000000e+01 1.77000000e+01 ... 6.20000000e+00
#   6.50000000e+00 6.80000000e+00]]

# %%
print(normalized_X)
# Out:
# [[6.31172263e-05 6.31172263e-05 6.31172263e-05 ... 4.03319076e-02
#   3.84383908e-02 3.78703358e-02]
#  [9.88972524e-04 1.02010643e-03 1.01588386e-03 ... 1.47995737e-04
#   1.28481551e-03 8.84509761e-04]
#  [1.36876189e-02 1.33293042e-02 1.29709896e-02 ... 2.72319119e-03
#   2.36487656e-03 2.14272149e-02]
#  [1.11857375e-03 1.17301743e-03 1.20948602e-03 ... 2.12946656e-04
#   1.82960451e-03 1.60805568e-03]
#  [9.24664233e-02 9.40792097e-02 9.51544007e-02 ... 3.33309200e-02
#   3.49437065e-02 3.65564929e-02]]

# %%
df.insert(16,'Alcohol_n',normalized_X[0])
df.insert(17,'Percentage Expenditure_n',normalized_X[1])
df.insert(18,'BMI_n',normalized_X[2])
df.insert(19,'GDP_n',normalized_X[3])
df.insert(20,'Thinness 1-19 Years_n',normalized_X[4])

# %%
df
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     AFGHANISTAN  2015  DEVELOPING              65.0            263.0
# 1     AFGHANISTAN  2014  DEVELOPING              59.9            271.0
# 2     AFGHANISTAN  2013  DEVELOPING              59.9            268.0
# 3     AFGHANISTAN  2012  DEVELOPING              59.5            272.0
# 4     AFGHANISTAN  2011  DEVELOPING              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2922     ZIMBABWE  2015  DEVELOPING              67.0            336.0
# 2923     ZIMBABWE  2014  DEVELOPING              59.2            371.0
# 2924     ZIMBABWE  2013  DEVELOPING              58.0            399.0
# 2925     ZIMBABWE  2012  DEVELOPING              56.6            429.0
# 2926     ZIMBABWE  2011  DEVELOPING              54.9            464.0
#
#       infant deaths  Alcohol  percentage expenditure  Measles    BMI   ...  \
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Measles ',
#        ' BMI ', 'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  10-19 years', 'Income composition of resources',
#        'Alcohol_n', 'Percentage Expenditure_n', 'BMI_n', 'GDP_n',
#        'Thinness 1-19 Years_n'],
#       dtype='object')

# %%
plt.boxplot(df['Life expectancy '])
plt.xlabel('Life Expectancy')
# Out:
# Text(0.5, 0, 'Life Expectancy')

# %%
AM = df['Adult Mortality']
plt.hist(AM,rwidth=0.9)
plt.xlabel('Adult Mortality')
# Out:
# Text(0.5, 0, 'Adult Mortality')

# %%
plt.figure(figsize=(7,5))
plt.bar(df.groupby('Year')['Year'].count().index,df.groupby('Year')['Life expectancy '].mean(),color='red',alpha=0.65)
plt.xlabel("Year",fontsize=12)
plt.ylabel("Avg Life_Expectancy",fontsize=12)
plt.title("Life_Expectancy w.r.t Year")
# Out:
# Text(0.5, 1.0, 'Life_Expectancy w.r.t Year')

# %%
plt.figure(figsize=(6,6))
plt.bar(df.groupby('Status')['Status'].count().index,df.groupby('Status')['Life expectancy '].mean())
plt.xlabel("Status",fontsize=12)
plt.ylabel("Avg Life_Expectancy",fontsize=12)
plt.title("Life_Expectancy w.r.t Status")
# Out:
# Text(0.5, 1.0, 'Life_Expectancy w.r.t Status')

# %%
data_country = df.groupby('Country')['Life expectancy '].mean()
data_country.plot(kind='bar', figsize=(50,15), fontsize=25)
plt.title("Life_Expectancy w.r.t Country",fontsize=40)
plt.xlabel("Country",fontsize=35)
plt.ylabel("Avg Life_Expectancy",fontsize=35)
# Out:
# Text(0, 0.5, 'Avg Life_Expectancy')

# %%
plt.figure(figsize=(18,40))

plt.subplot(6,3,1)
plt.scatter(df["Life expectancy "], df["Adult Mortality"])
plt.title("LifeExpectancy vs AdultMortality")

plt.subplot(6,3,2)
plt.scatter(df["Life expectancy "], df["infant deaths"])
plt.title("LifeExpectancy vs Infant_Deaths")

plt.subplot(6,3,3)
plt.scatter(df["Life expectancy "], df["Alcohol"])
plt.title("LifeExpectancy vs Alcohol")
# Out:
# Text(0.5, 1.0, 'LifeExpectancy vs Alcohol')

# %%
from scipy import stats
from statsmodels.stats import weightstats as stests

ztest ,pval = stests.ztest(df["Life expectancy "], x2=None, value=70.42248648648648)
#print(pval)
if pval < 0.05:
    print("reject null hypothesis")
else:
    print("accept null hypothesis")

#ztest ,pval1 = stests.ztest(df.groupby('Status')['Life expectancy '].mean(), x2=df.groupby('Status')['Life expectancy '].mean())
ztest ,pval1 = stests.ztest(df.groupby('Status')['Life expectancy '].mean(), x2=df.groupby('Status')['Life expectancy '].mean(), value=12.470135,alternative='two-sided')
if pval1 < 0.05:
    print("reject null hypothesis")
else:
    print("accept null hypothesis")
#print(pval1)
print(df.groupby('Status')['Life expectancy '].mean())
# Out:
# accept null hypothesis
# accept null hypothesis
# Status
# DEVELOPED     80.735625
# DEVELOPING    68.265490
# Name: Life expectancy , dtype: float64

# %%
grp=df.groupby('Status')
col=grp[['Life expectancy ','Adult Mortality','Alcohol','infant deaths','percentage expenditure','Measles ',' BMI ','Diphtheria ','GDP',' HIV/AIDS','Population',' thinness  10-19 years','Income composition of resources']] 
corr=col.corr(method='pearson')
corrf=corr.round(3)
#print(corrf.to_string())
print(corrf)
# Out:
#                                             Life expectancy   Adult Mortality  \
# Status
# DEVELOPED  Life expectancy                             1.000           -0.505
#            Adult Mortality                            -0.505            1.000
#            Alcohol                                    -0.058            0.026
#            infant deaths                              -0.069           -0.237
#            percentage expenditure                      0.275           -0.157
#            Measles                                    -0.008            0.020
#             BMI                                       -0.100           -0.001
#            Diphtheria                                  0.013           -0.015
#            GDP                                         0.268           -0.170
#             HIV/AIDS                                   0.000            0.000
#            Population                                  0.025           -0.066
# ...
